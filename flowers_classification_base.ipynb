# %%
from collections import Counter
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# tf.keras.utils.set_random_seed(42)
# tf.config.experimental.enable_op_determinism()

from tensorflow.keras import layers

import warnings

warnings.filterwarnings("ignore")
# Out:
# 2023-12-06 11:12:26.210291: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-06 11:12:26.259156: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-06 11:12:26.259189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-06 11:12:26.260338: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-06 11:12:26.267730: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-06 11:12:27.323438: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from dataclasses import dataclass


@dataclass
class Parameters:
    learning_rate: float = 0.001
    batch_size: int = 32
    data_dir = Path('data')
    train_dir = data_dir / 'flower_photos'
    verbose = 1
    epochs = 20
    img_size = 224
    img_shape = (img_size, img_size, 3)
    class_names = None
    seed = 42

# %%
data_dir = Path('data')
train_dir = data_dir / 'flower_photos'

# %%
# Your existing code
batch_size = 32
img_height = 224
img_width = 224

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(img_height, img_width),
    batch_size=batch_size)

class_names = train_ds.class_names
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
image_batch, label_batch = next(iter(train_ds))
image_batch.shape
# Out:
# TensorShape([32, 224, 224, 3])

# %%
def plot_images(dataset, class_names, num_images=25):
    # Get a batch of images and labels from the dataset
    image_batch, label_batch = next(iter(dataset))

    plt.figure(figsize=(10, 10))
    sns.set_style("whitegrid")
    for i in range(num_images):
        ax = plt.subplot(5, 5, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        label = class_names[label_batch[i]]
        plt.title(label)
    plt.tight_layout()

plot_images(train_ds, class_names=train_ds.class_names)

# %%
def plot_class_distribution(train_ds, test_ds, class_names):
    # Get the class distributions in the datasets
    train_class_distribution = Counter([class_names[label] for images, labels in train_ds for label in labels])
    test_class_distribution = Counter([class_names[label] for images, labels in test_ds for label in labels])

    # Sort the keys and values of the class distributions
    train_keys, train_values = zip(*sorted(train_class_distribution.items()))
    test_keys, test_values = zip(*sorted(test_class_distribution.items()))

    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))

    # Plot the class distribution in the training dataset
    sns.barplot(x=list(train_keys), y=list(train_values), ax=axs[0], palette="Blues_d")
    axs[0].set_title('Class Distribution in Training Dataset')
    axs[0].tick_params(axis='x', rotation=45)

    # Plot the class distribution in the test dataset
    sns.barplot(x=list(test_keys), y=list(test_values), ax=axs[1], palette="Greens_d")
    axs[1].set_title('Class Distribution in Test Dataset')
    axs[1].tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

plot_class_distribution(train_ds, val_ds, class_names)

# %%
preprocessing_layer = tf.keras.Sequential([
    layers.Rescaling(1./255),
])
augmentation_layer = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical", seed=42),
    layers.RandomRotation(0.2, seed=42),
    layers.RandomZoom(0.3, seed=42),
    layers.RandomTranslation(0.2, 0.2, seed=42),
    ])

# %%
def create_model():
    tf.keras.backend.clear_session()
    model = tf.keras.Sequential([
    tf.keras.Input(shape=(img_height, img_width, 3)),
    preprocessing_layer,
    augmentation_layer,
    layers.Conv2D(16, 7, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 7, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 7, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 7, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(256, 7, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.2),
    layers.Dense(len(class_names))
    ])  
    return model

# %%
model = create_model()
model.summary(expand_nested=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | rescaling (Rescaling)      (None, 224, 224, 3)       0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  sequential_1 (Sequential)   (None, 224, 224, 3)       0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | random_flip (RandomFlip)   (None, 224, 224, 3)       0        |
# |                                                               |
# | random_rotation (RandomRo  (None, 224, 224, 3)       0        |
# | tation)                                                       |
# |                                                               |
# | random_zoom (RandomZoom)   (None, 224, 224, 3)       0        |
# |                                                               |
# | random_translation (Rando  (None, 224, 224, 3)       0        |
# | mTranslation)                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  conv2d (Conv2D)             (None, 224, 224, 16)      2368
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      25120
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        100416
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               8320
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 137381 (536.64 KB)
# Trainable params: 137125 (535.64 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
# define optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
#define loss
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#compile model
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-8, mode='min')
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('checkpoints/model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
callbacks = [reduce_lr, model_checkpoint]

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
#fit model
epochs=100
history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs=epochs, 
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3943 - accuracy: 0.3941
# Epoch 1: val_loss improved from inf to 1.57619, saving model to checkpoints/model.h5
# 92/92 [==============================] - 52s 541ms/step - loss: 1.3943 - accuracy: 0.3941 - val_loss: 1.5762 - val_accuracy: 0.3515 - lr: 0.0010
# Epoch 2/100
# 92/92 [==============================] - ETA: 0s - loss: 1.3154 - accuracy: 0.4595
# Epoch 2: val_loss improved from 1.57619 to 1.34821, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 547ms/step - loss: 1.3154 - accuracy: 0.4595 - val_loss: 1.3482 - val_accuracy: 0.5341 - lr: 0.0010
# Epoch 3/100
# 92/92 [==============================] - ETA: 0s - loss: 1.2002 - accuracy: 0.5181
# Epoch 3: val_loss did not improve from 1.34821
# 92/92 [==============================] - 50s 545ms/step - loss: 1.2002 - accuracy: 0.5181 - val_loss: 1.3788 - val_accuracy: 0.4673 - lr: 0.0010
# Epoch 4/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1477 - accuracy: 0.5460
# Epoch 4: val_loss improved from 1.34821 to 1.23768, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 536ms/step - loss: 1.1477 - accuracy: 0.5460 - val_loss: 1.2377 - val_accuracy: 0.5095 - lr: 0.0010
# Epoch 5/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1354 - accuracy: 0.5504
# Epoch 5: val_loss improved from 1.23768 to 1.21697, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 537ms/step - loss: 1.1354 - accuracy: 0.5504 - val_loss: 1.2170 - val_accuracy: 0.5327 - lr: 0.0010
# Epoch 6/100
# 92/92 [==============================] - ETA: 0s - loss: 1.0501 - accuracy: 0.5889
# Epoch 6: val_loss improved from 1.21697 to 1.03318, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 536ms/step - loss: 1.0501 - accuracy: 0.5889 - val_loss: 1.0332 - val_accuracy: 0.6035 - lr: 0.0010
# Epoch 7/100
# 92/92 [==============================] - ETA: 0s - loss: 0.9973 - accuracy: 0.6008
# Epoch 7: val_loss improved from 1.03318 to 0.96419, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s
100
# 92/92 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.6897
# Epoch 18: val_loss improved from 0.84943 to 0.82759, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 542ms/step - loss: 0.7903 - accuracy: 0.6897 - val_loss: 0.8276 - val_accuracy: 0.6866 - lr: 1.0000e-04
# Epoch 19/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7815 - accuracy: 0.6928
# Epoch 19: val_loss improved from 0.82759 to 0.81629, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 538ms/step - loss: 0.7815 - accuracy: 0.6928 - val_loss: 0.8163 - val_accuracy: 0.6907 - lr: 1.0000e-04
# Epoch 20/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.6918
# Epoch 20: val_loss did not improve from 0.81629
# 92/92 [==============================] - 49s 531ms/step - loss: 0.7846 - accuracy: 0.6918 - val_loss: 0.8224 - val_accuracy: 0.6907 - lr: 1.0000e-04
# Epoch 21/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7853 - accuracy: 0.6849
# Epoch 21: val_loss did not improve from 0.81629
# 92/92 [==============================] - 50s 542ms/step - loss: 0.7853 - accuracy: 0.6849 - val_loss: 0.8177 - val_accuracy: 0.6907 - lr: 1.0000e-04
# Epoch 22/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7708 - accuracy: 0.6986
# Epoch 22: val_loss did not improve from 0.81629
# 92/92 [==============================] - 49s 538ms/step - loss: 0.7708 - accuracy: 0.6986 - val_loss: 0.8301 - val_accuracy: 0.6812 - lr: 1.0000e-04
# Epoch 23/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7727 - accuracy: 0.7132
# Epoch 23: val_loss improved from 0.81629 to 0.80827, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 541ms/step - loss: 0.7727 - accuracy: 0.7132 - val_loss: 0.8083 - val_accuracy: 0.6935 - lr: 1.0000e-04
# Epoch 24/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7777 - accuracy: 0.6955
# Epoch 24: val_loss did not improve from 0.80827
# 92/92 [==============================] - 50s 546ms/step - loss: 0.7777 - accuracy: 0.6955 - val_loss: 0.8309 - val_accuracy: 0.6839 - lr: 1.0000e-04
# Epoch 25/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7615 - accuracy: 0.6986
# Epoch 25: val_loss improved from 0.80827 to 0.79622, saving model to checkpoints/model.h5
# 92/92 [==============================] - 51s 556ms/step - loss: 0.7615 - accuracy: 0.6986 - val_loss: 0.7962 - val_accuracy: 0.6948 - lr: 1.0000e-04
# Epoch 26/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7468 - accuracy: 0.7122
# Epoch 26: val_loss did not improve from 0.79622
# 92/92 [==============================] - 50s 547ms/step - loss: 0.7468 - accuracy: 0.7122 - val_loss: 0.7977 - val_accuracy: 0.7016 - lr: 1.0000e-04
# Epoch 27/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7564 - accuracy: 0.7027
# Epoch 27: val_loss did not improve from 0.79622
# 92/92 [==============================] - 50s 544ms/step - loss: 0.7564 - accuracy: 0.7027 - val_loss: 0.8214 - val_accuracy: 0.6894 - lr: 1.0000e-04
# Epoch 28/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7527 - accuracy: 0.7067
# Epoch 28: val_loss did not improve from 0.79622
# 92/92 [==============================] - 51s 553ms/step - loss: 0.7527 - accuracy: 0.7067 - val_loss: 0.8155 - val_accuracy: 0.6935 - lr: 1.0000e-04
# Epoch 29/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7291 - accuracy: 0.7204
# Epoch 29: val_loss did not improve from 0.79622
# 92/92 [==============================] - 49s 535ms/step - loss: 0.7291 - accuracy: 0.7204 - val_loss: 0.8305 - val_accuracy: 0.6853 - lr: 1.0000e-04
# Epoch 30/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7278 - accuracy: 0.7193
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 30: val_loss did not improve from 0.79622
# 92/92 [==============================] - 49s 535ms/step - loss: 0.7278 - accuracy: 0.7193 - val_loss: 0.8102 - val_accuracy: 0.6866 - lr: 1.0000e-04
# Epoch 31/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7339 - accuracy: 0.7193
# Epoch 31: val_loss improved from 0.79622 to 0.78805, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 538ms/step - loss: 0.7339 - accuracy: 0.7193 - val_loss: 0.7881 - val_accuracy: 0.7003 - lr: 1.0000e-05
# Epoch 32/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.7217
# Epoch 32: val_loss improved from 0.78805 to 0.77939, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 540ms/step - loss: 0.7195 - accuracy: 0.7217 - val_loss: 0.7794 - val_accuracy: 0.6989 - lr: 1.0000e-05
# Epoch 33/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7263 - accuracy: 0.7187
# Epoch 33: val_loss improved from 0.77939 to 0.77870, saving model to checkpoints/model.h5
# 92/92 [==============================] - 51s 553ms/step - loss: 0.7263 - accuracy: 0.7187 - val_loss: 0.7787 - val_accuracy: 0.7016 - lr: 1.0000e-05
# Epoch 34/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7280 - accuracy: 0.7170
# Epoch 34: val_loss improved from 0.77870 to 0.77634, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 535ms/step - loss: 0.7280 - accuracy: 0.7170 - val_loss: 0.7763 - val_accuracy: 0.6989 - lr: 1.0000e-05
# Epoch 35/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.7125
# Epoch 35: val_loss improved from 0.77634 to 0.77514, saving model to checkpoints/model.h5
# 92/92 [==============================] - 50s 539ms/step - loss: 0.7325 - accuracy: 0.7125 - val_loss: 0.7751 - val_accuracy: 0.7030 - lr: 1.0000e-05
# Epoch 36/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7200
# Epoch 36: val_loss did not improve from 0.77514
# 92/92 [==============================] - 49s 535ms/step - loss: 0.7126 - accuracy: 0.7200 - val_loss: 0.7807 - val_accuracy: 0.6989 - lr: 1.0000e-05
# Epoch 37/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.7221
# Epoch 37: val_loss did not improve from 0.77514
# 92/92 [==============================] - 49s 533ms/step - loss: 0.7163 - accuracy: 0.7221 - val_loss: 0.7773 - val_accuracy: 0.7030 - lr: 1.0000e-05
# Epoch 38/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7321 - accuracy: 0.7210
# Epoch 38: val_loss improved from 0.77514 to 0.76693, saving model to checkpoints/model.h5
# 92/92 [==============================] - 49s 533ms/step - loss: 0.7321 - accuracy: 0.7210 - val_loss: 0.7669 - val_accuracy: 0.7057 - lr: 1.0000e-05
# Epoch 39/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7241 - accuracy: 0.7183
# Epoch 39: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 532ms/step - loss: 0.7241 - accuracy: 0.7183 - val_loss: 0.7736 - val_accuracy: 0.7057 - lr: 1.0000e-05
# Epoch 40/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7150 - accuracy: 0.7248
# Epoch 40: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 532ms/step - loss: 0.7150 - accuracy: 0.7248 - val_loss: 0.7742 - val_accuracy: 0.7071 - lr: 1.0000e-05
# Epoch 41/100
# 92/92 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7170 - accuracy: 0.7187 - val_loss: 0.7695 - val_accuracy: 0.7071 - lr: 1.0000e-08
# Epoch 82/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7058 - accuracy: 0.7268
# Epoch 82: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7058 - accuracy: 0.7268 - val_loss: 0.7684 - val_accuracy: 0.7084 - lr: 1.0000e-08
# Epoch 83/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7164 - accuracy: 0.7309
# Epoch 83: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7164 - accuracy: 0.7309 - val_loss: 0.7686 - val_accuracy: 0.7084 - lr: 1.0000e-08
# Epoch 84/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7175 - accuracy: 0.7187
# Epoch 84: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7175 - accuracy: 0.7187 - val_loss: 0.7689 - val_accuracy: 0.7084 - lr: 1.0000e-08
# Epoch 85/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7166
# Epoch 85: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7221 - accuracy: 0.7166 - val_loss: 0.7688 - val_accuracy: 0.7044 - lr: 1.0000e-08
# Epoch 86/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7071 - accuracy: 0.7153
# Epoch 86: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7071 - accuracy: 0.7153 - val_loss: 0.7687 - val_accuracy: 0.7044 - lr: 1.0000e-08
# Epoch 87/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.7180
# Epoch 87: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7161 - accuracy: 0.7180 - val_loss: 0.7696 - val_accuracy: 0.7044 - lr: 1.0000e-08
# Epoch 88/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7134 - accuracy: 0.7231
# Epoch 88: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7134 - accuracy: 0.7231 - val_loss: 0.7701 - val_accuracy: 0.7016 - lr: 1.0000e-08
# Epoch 89/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7299
# Epoch 89: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 528ms/step - loss: 0.7126 - accuracy: 0.7299 - val_loss: 0.7694 - val_accuracy: 0.7044 - lr: 1.0000e-08
# Epoch 90/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7352 - accuracy: 0.7139
# Epoch 90: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7352 - accuracy: 0.7139 - val_loss: 0.7697 - val_accuracy: 0.7071 - lr: 1.0000e-08
# Epoch 91/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.7234
# Epoch 91: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7090 - accuracy: 0.7234 - val_loss: 0.7696 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 92/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7141 - accuracy: 0.7265
# Epoch 92: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7141 - accuracy: 0.7265 - val_loss: 0.7693 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 93/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.7224
# Epoch 93: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7192 - accuracy: 0.7224 - val_loss: 0.7696 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 94/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7136
# Epoch 94: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7221 - accuracy: 0.7136 - val_loss: 0.7683 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 95/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7183 - accuracy: 0.7153
# Epoch 95: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7183 - accuracy: 0.7153 - val_loss: 0.7700 - val_accuracy: 0.7030 - lr: 1.0000e-08
# Epoch 96/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7155 - accuracy: 0.7275
# Epoch 96: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 530ms/step - loss: 0.7155 - accuracy: 0.7275 - val_loss: 0.7700 - val_accuracy: 0.7016 - lr: 1.0000e-08
# Epoch 97/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7128 - accuracy: 0.7251
# Epoch 97: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 531ms/step - loss: 0.7128 - accuracy: 0.7251 - val_loss: 0.7702 - val_accuracy: 0.7030 - lr: 1.0000e-08
# Epoch 98/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.7146
# Epoch 98: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 528ms/step - loss: 0.7209 - accuracy: 0.7146 - val_loss: 0.7704 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 99/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.7197
# Epoch 99: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7124 - accuracy: 0.7197 - val_loss: 0.7705 - val_accuracy: 0.7057 - lr: 1.0000e-08
# Epoch 100/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7127 - accuracy: 0.7241
# Epoch 100: val_loss did not improve from 0.76693
# 92/92 [==============================] - 49s 529ms/step - loss: 0.7127 - accuracy: 0.7241 - val_loss: 0.7704 - val_accuracy: 0.7044 - lr: 1.0000e-08
